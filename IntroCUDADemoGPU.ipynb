# %% [markdown]
# <a href="https://colab.research.google.com/github/Balachandar-Ganesan/GraphRAG/blob/main/IntroCUDADemoGPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# Check if CUDA is available and set the device accordingly
if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Using GPU:", torch.cuda.get_device_name(0))
else:
    device = torch.device('cpu')
    print("Using CPU")

# Create a tensor (a multi-dimensional array) and move it to the selected device
x = torch.randn(10, 10).to(device)
y = torch.randn(10, 10).to(device)

# Perform a matrix multiplication on the selected device
# %timeit z = torch.matmul(x, y)
# Out:
# Using CPU
# 3.11 µs ± 300 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# !nvidia-smi
# Out:
# Sun Mar 15 12:16:31 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
import time
device = torch.device('cuda')
x = torch.randn(10, 10).to(device)
y = torch.randn(10, 10).to(device)

# %%
# ... (define A_gpu, B_gpu and move them to 'cuda' device) ...

torch.cuda.synchronize() # Wait for all previous CUDA operations to complete
start_time = time.time()

C_gpu = torch.matmul(x, y)

torch.cuda.synchronize() # Wait for the matmul to complete
end_time = time.time()

print(f"GPU matmul time: {end_time - start_time} seconds")
# Out:
# GPU matmul time: 0.15894460678100586 seconds
