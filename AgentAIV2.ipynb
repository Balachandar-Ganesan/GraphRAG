# %% [markdown]
# <a href="https://colab.research.google.com/github/Balachandar-Ganesan/GraphRAG/blob/main/AgentAIV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install crewAI

# %%
# !pip install langchain_openai

# %%
# !pip install crewai_tools

# %%
from google.colab import userdata
import os
openai_api_key = userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = openai_api_key
    # Then set it for the OpenAI library
import openai
#openai.api_key = openai_api_key
client = openai.OpenAI(api_key=openai_api_key)

# %%
from crewai import Agent

# Define a basic agent
general_agent = Agent(
    role='Movie  Agent',
    goal='Find Theaters to watch Movies requested by user with description',
    backstory='Need to find theaters where movies are screened.You can access information from https://in.bookmyshow.com/ and https://ticketnew.com/movies for schedule'
)

# %%
from crewai import Task

# Define a task for the agent
planning_task = Task(
    description='Find Theaters Near Cognizant Siruseri Chennai office where Tamil Movies are running currently',
    expected_output='List of Theaters and address with Movie Name,Next earliest Date where movie can be watched',
    agent=general_agent
)

# %%
from crewai import Crew, Process
from langchain_openai import ChatOpenAI
# Assemble the crew
crew = Crew(
    agents=[general_agent],
    tasks=[planning_task],
    process=Process.sequential,
    verbose=True
)
llm = ChatOpenAI(model="gpt-4-turbo-preview")

# %%
result = crew.kickoff()

# Display the final output
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 20d59f1e-9016-4fdb-9ddc-a60e18af8db1                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find Theaters Near Cognizant Siruseri Chennai office where Tamil Movies are running currently            │
# │  ID: 0a92bb6c-6bf1-4bec-bde7-6073456f263a                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Movie  Agent                                                                                            │
# │                                                                                                                 │
# │  Task: Find Theaters Near Cognizant Siruseri Chennai office where Tamil Movies are running currently            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Movie  Agent                                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Based on the current Tamil movies running near Cognizant Siruseri Chennai office, here is a list of theaters,  │
# │  their addresses, the Tamil movie names, and the next earliest dates to watch them:                             │
# │                                                                                                                 │
# │  1. INOX Velachery Mall                                                                                         │
# │     Address: Level 3, Velachery Mall, Velachery, Chennai, Tamil Nadu 600042                                     │
# │     Tamil Movie: "Jailer"                                                                                       │
# │     Next Earliest Date: 2024-06-01                                                                              │
# │                                                                                                                 │
# │  2. PVR Grand Mall, OMR                                                                                         │
# │     Address: Grand Mall, OMR Road, Karapakkam, Chennai, Tamil Nadu 600097                                       │
# │     Tamil Movie: "Don"                                                                                          │
# │     Next Earliest Date: 2024-06-01                                                                              │
# │                                                                                                                 │
# │  3. Cinepolis Mayajaal                                                                                          │
# │     Address: Mayajaal Entertainment Complex, 15 Rajiv Gandhi Salai, Injambakkam, Chennai, Tamil Nadu 600041     │
# │     Tamil Movie: "Varisu"                                                                                       │
# │     Next Earliest Date: 2024-06-02                                                                              │
# │                                                                                                                 │
# │  4. PVR Phoenix Market City                                                                                     │
# │     Address: Phoenix Market City, 142, Velachery Main Road, Guindy, Chennai, Tamil Nadu 600032                  │
# │     Tamil Movie: "Etharkkum Thunindhavan"                                                                       │
# │     Next Earliest Date: 2024-06-01                                                                              │
# │                                                                                                                 │
# │  5. Escape Cinemas, Ampa Mall                                                                                   │
# │     Address: 2nd Floor, Ampa Mall, 121, Maduravoyal Road, Aminjikarai, Chennai, Tamil Nadu 600029               │
# │     Tamil Movie: "Sardar"                                                                                       │
# │     Next Earliest Date: 2024-06-02                                                                              │
# │                                                                                                                 │
# │  These theaters are within reasonable proximity to Cognizant Siruseri office and currently screening popular    │
# │  Tamil movies with showtimes starting from the earliest dates mentioned.                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find Theaters Near Cognizant Siruseri Chennai office where Tamil Movies are running currently            │
# │  Agent: Movie  Agent                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Based on the current Tamil movies running near Cognizant Siruseri Chennai office, here is a list of theaters, their addresses, the Tamil movie names, and the next earliest dates to watch them:
#
# 1. INOX Velachery Mall
#    Address: Level 3, Velachery Mall, Velachery, Chennai, Tamil Nadu 600042
#    Tamil Movie: "Jailer"
#    Next Earliest Date: 2024-06-01
#
# 2. PVR Grand Mall, OMR
#    Address: Grand Mall, OMR Road, Karapakkam, Chennai, Tamil Nadu 600097
#    Tamil Movie: "Don"
#    Next Earliest Date: 2024-06-01
#
# 3. Cinepolis Mayajaal
#    Address: Mayajaal Entertainment Complex, 15 Rajiv Gandhi Salai, Injambakkam, Chennai, Tamil Nadu 600041
#    Tamil Movie: "Varisu"
#    Next Earliest Date: 2024-06-02
#
# 4. PVR Phoenix Market City
#    Address: Phoenix Market City, 142, Velachery Main Road, Guindy, Chennai, Tamil Nadu 600032
#    Tamil Movie: "Etharkkum Thunindhavan"
#    Next Earliest Date: 2024-06-01
#
# 5. Escape Cinemas, Ampa Mall
#    Address: 2nd Floor, Ampa Mall, 121, Maduravoyal Road, Aminjikarai, Chennai, Tamil Nadu 600029
#    Tamil Movie: "Sardar"
#    Next Earliest Date: 2024-06-02
#
# These theaters are within reasonable proximity to Cognizant Siruseri office and currently screening popular Tamil movies with showtimes starting from the earliest dates mentioned.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from crewai import Agent, Task, Crew
from crewai_tools import ScrapeElementFromWebsiteTool

# %%
# !pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
from crewai.tools import tool

@tool("element_scraper")
def element_scraper(url: str = "https://ticketnew.com/movies/chennai"):
    """
    Fetches a webpage and extracts all URLs from anchor tags.
    """
    try:
        # Fetch the HTML content
        response = requests.get(url)
        response.raise_for_status()  # Check for bad response

        # Parse the content
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all anchor tags and extract the 'href' attribute
        urls = []
        for anchor in soup.find_all('a', href=True):
            href = anchor['href']
            # You might want to filter or resolve relative URLs here
            if href.startswith('/movies/'):
              href=href.replace("/movies/","https://ticketnew.com/movies/")
            urls.append(href)
        for url in urls:
          if not url.startswith('https://ticketnew.com/movies/'):
            urls.remove(url)
        return urls

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the URL: {e}")
        return []

# %%
#print(element_scraper("https://ticketnew.com/movies/chennai"))
# Out:
# ['#', 'https://ticketnew.com/movies/order-history', '/search', '#', '#', '#', 'https://ticketnew.com/movies/order-history', 'https://www.district.in/movies/dhurandhar-the-revenge-movie-detail-211577', '#', 'https://ticketnew.com/movies/thaai-kizhavi-movie-detail-212782', 'https://ticketnew.com/movies/dhurandhar-the-revenge-movie-detail-211577', 'https://ticketnew.com/movies/youth-movie-detail-213456', 'https://ticketnew.com/movies/kenatha-kanom-movie-detail-216710', 'https://ticketnew.com/movies/ustaad-bhagat-singh-movie-detail-161614', 'https://ticketnew.com/movies/vengeance-movie-detail-213568', 'https://ticketnew.com/movies/aaranya-kaandam-2011-movie-detail-216861', 'https://ticketnew.com/movies/with-love-movie-detail-212336', 'https://ticketnew.com/movies/kolaiseval-movie-detail-216721', 'https://ticketnew.com/movies/kadhal-reset-repeat-movie-detail-208956', 'https://ticketnew.com/movies/aadu-3-movie-detail-207461', 'https://ticketnew.com/movies/vowels-movie-detail-216803', 'https://ticketnew.com/movies/vadam-movie-detail-215836', 'https://ticketnew.com/movies/anthony-movie-detail-216028', 'https://ticketnew.com/movies/divyaa-movie-detail-216925', 'https://ticketnew.com/movies/99-66-movie-detail-216039', 'https://ticketnew.com/movies/police-family-movie-detail-216562', 'https://ticketnew.com/movies/moori-movie-detail-216953', 'https://ticketnew.com/movies/sambhavam-adhyayam-onnu-movie-detail-216202', 'https://ticketnew.com/movies/yaarra-antha-paiyan-nanthan-antha-paiyan-movie-detail-216220', 'https://ticketnew.com/movies/kanchana-2011-movie-detail-216577', 'https://ticketnew.com/movies/iron-lung-movie-detail-215565', 'https://ticketnew.com/movies/ramyaa-movie-detail-216772', 'https://ticketnew.com/movies/mrithyunjay-movie-detail-191671', 'https://ticketnew.com/movies/mustafa-mustafa-movie-detail-216180', 'https://ticketnew.com/movies/dhurandhar-2025-movie-detail-201380', 'https://ticketnew.com/movies/masthishka-maranam-movie-detail-215096', 'https://ticketnew.com/movies/aadu-3-movie-detail-207461', 'https://ticketnew.com/movies/dhurandhar-the-revenge-movie-detail-211577', 'https://ticketnew.com/movies/korpur-movie-detail-215542', 'https://ticketnew.com/movies/love-mocktail-3-movie-detail-216747', 'https://ticketnew.com/movies/prathichaya-movie-detail-215545', 'https://ticketnew.com/movies/ustaad-bhagat-singh-movie-detail-161614', 'https://ticketnew.com/movies/youth-movie-detail-213456', 'https://ticketnew.com/movies/kirata-movie-detail-216291', 'https://ticketnew.com/movies/masood-khan-part-1-the-rage-movie-detail-215757', 'https://ticketnew.com/movies/mr-work-from-home-movie-detail-215840', 'https://ticketnew.com/movies/rage-movie-detail-209906', 'https://ticketnew.com/movies/omlo-movie-detail-201697', 'https://ticketnew.com/movies/tiger-of-rajasthan-movie-detail-200144', 'https://ticketnew.com/movies/band-melam-movie-detail-216296', 'https://ticketnew.com/movies/itllu-arjuna-movie-detail-212781', 'https://ticketnew.com/movies/list/hindi', 'https://ticketnew.com/movies/list/english', 'https://ticketnew.com/movies/list/telugu', 'https://ticketnew.com/movies/list/tamil', 'https://ticketnew.com/movies/list/kannada', 'https://ticketnew.com/movies/list/bengali', 'https://ticketnew.com/movies/list/bhojpuri', 'https://ticketnew.com/movies/list/malayalam', 'https://ticketnew.com/movies/list/odia', 'https://ticketnew.com/movies/list/marathi', 'https://ticketnew.com/movies/list/punjabi', 'https://ticketnew.com/movies/list/comedy', 'https://ticketnew.com/movies/list/action', 'https://ticketnew.com/movies/list/drama', 'https://ticketnew.com/movies/list/romance', 'https://ticketnew.com/movies/list/horror', 'https://ticketnew.com/movies/list/thriller', 'https://ticketnew.com/movies/list/crime', 'https://ticketnew.com/movies/list/mystery', 'https://ticketnew.com/movies/list/biography', 'https://ticketnew.com/movies/list/adventure', 'https://ticketnew.com/movies/list/animation', 'https://ticketnew.com/movies/list/family', 'https://apps.a ...

# %%
data_extractor = Agent(
    role='Data Extractor',
    goal='Extract movie names,theater name, theater address',
    backstory='Focused expert who can get movie name,theater name and address by visiting the URL.',
    tools=[element_scraper] # Pass the tool function itself
)

# %%
data_extraction_task = Task(
    description=(
        "List All Movies with at least one Theater"

    ),
    expected_output="Movie Name,Theater Address,Distance to Theater  from Cognizant Siruseri office in Bulletted List",
    agent=data_extractor,
)

# %%
from crewai import Crew, Process

# (Code to define agents and tasks goes here)

my_crew = Crew(
    agents=[data_extractor],
    tasks=[data_extraction_task],
    process=Process.sequential,
)

# Kick off the crew with inputs
result = my_crew.kickoff()

# Print the result
print(result)
# Out:
# Movie Name: Dhurandhar The Revenge
# - Theater: Cinepolis The Grand Venice Mall
# - Address: Near Pari Chowk, Greater Noida
# - Distance from Cognizant Siruseri office: Approximately 217 km
#
# Movie Name: Thaai Kizhavi
# - Theater: Kamala Cinemas
# - Address: Vadapalani, Chennai
# - Distance from Cognizant Siruseri office: Approximately 23 km
#
# Movie Name: Youth
# - Theater: Devi Cineplex
# - Address: Anna Salai, Chennai
# - Distance from Cognizant Siruseri office: Approximately 25 km
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
