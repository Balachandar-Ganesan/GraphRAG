# %%
# !pip install contextgem
# Out:
# Collecting contextgem
#   Downloading contextgem-0.4.0-py3-none-any.whl.metadata (20 kB)
# Collecting aiolimiter<2.0.0,>=1.2.1 (from contextgem)
#   Downloading aiolimiter-1.2.1-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from contextgem) (3.1.6)
# Collecting litellm<2.0.0,>=1.68.0 (from contextgem)
#   Downloading litellm-1.70.2-py3-none-any.whl.metadata (38 kB)
# Collecting loguru<0.8.0,>=0.7.3 (from contextgem)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.6 in /usr/local/lib/python3.11/dist-packages (from contextgem) (2.11.4)
# Collecting python-ulid<4.0.0,>=3.0.0 (from contextgem)
#   Downloading python_ulid-3.0.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torch<3.0.0,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from contextgem) (2.6.0+cu124)
# Collecting wtpsplit<3.0.0,>=2.1.4 (from contextgem)
#   Downloading wtpsplit-2.1.5-py3-none-any.whl.metadata (923 bytes)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.5->contextgem) (3.0.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.68.0->contextgem) (3.11.15)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.68.0->contextgem) (8.2.0)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.68.0->contextgem) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.68.0->contextgem) (8.7.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.68.0->contextgem) (4.23.0)
# Collecting openai<1.76.0,>=1.68.2 (from litellm<2.0.0,>=1.68.0->contextgem)
#   Downloading openai-1.75.0-py3-none-any.whl.metadata (25 kB)
# Collecting python-dotenv>=0.2.0 (from litellm<2.0.0,>=1.68.0->contextgem)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.68.0->contextgem) (0.9.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.68.0->contextgem) (0.21.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.10.6->contextgem) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.10.6->contextgem) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.10.6->contextgem) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.10.6->contextgem) (0.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.6.0->contextgem) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.6.0->contextgem) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.6.0->contextgem) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.6.0->contextgem) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.6.0->contextgem) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.6.0->contextgem) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0.0,>=2.6.0->contextgem)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.6.0->contextgem) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.6.0->contextgem) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.6.0->contextgem) (1.3.0)
# Requirement already satisfied: transformers>=4.22.2 in /usr/local/lib/python3.11/dist-packages (from wtpsplit<3.0.0,>=2.1.4->contextgem) (4.51.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from wtpsplit<3.0.0,>=2.1.4->contextgem) (0.31.2)
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from wtpsplit<3.0.0,>=2.1.4->contextgem) (2.0.2)
# Requirement already satisfied: scikit-learn>=1 in /usr/local/lib/python3.11/dist-packages (from wtpsplit<3.0.0,>=2.1.4->contextgem) (1.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from wtpsplit<3.0.0,>=2.1.4->contextgem) (4.67.1)
# Collecting skops (from wtpsplit<3.0.0,>=2.1.4->contextgem)
#   Downloading skops-0.11.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.11/dist-packages (from wtpsplit<3.0.0,>=2.1.4->contextgem) (2.2.2)
# Collecting cached_property (from wtpsplit<3.0.0,>=2.1.4->contextgem)
#   Downloading cached_property-2.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting mosestokenizer (from wtpsplit<3.0.0,>=2.1.4->contextgem)
#   Downloading mosestokenizer-1.2.1.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Collecting adapters>=1.0.1 (from wtpsplit<3.0.0,>=2.1.4->contextgem)
#   Downloading adapters-1.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from adapters>=1.0.1->wtpsplit<3.0.0,>=2.1.4->contextgem) (24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm<2.0.0,>=1.68.0->contextgem) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm<2.0.0,>=1.68.0->contextgem) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm<2.0.0,>=1.68.0->contextgem) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm<2.0.0,>=1.68.0->contextgem) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm<2.0.0,>=1.68.0->contextgem) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.68.0->contextgem) (3.21.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.68.0->contextgem) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.68.0->contextgem) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.68.0->contextgem) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.68.0->contextgem) (0.24.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<1.76.0,>=1.68.2->litellm<2.0.0,>=1.68.0->contextgem) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<1.76.0,>=1.68.2->litellm<2.0.0,>=1.68.0->contextgem) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<1.76.0,>=1.68.2->litellm<2.0.0,>=1.68.0->contextgem) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->wtpsplit<3.0.0,>=2.1.4->contextgem) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->wtpsplit<3.0.0,>=2.1.4->contextgem) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1->wtpsplit<3.0.0,>=2.1.4->contextgem) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1->wtpsplit<3.0.0,>=2.1.4->contextgem) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1->wtpsplit<3.0.0,>=2.1.4->contextgem) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1->wtpsplit<3.0.0,>=2.1.4->contextgem) (3.6.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.7.0->litellm<2.0.0,>=1.68.0->contextgem) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.7.0->litellm<2.0.0,>=1.68.0->contextgem) (2.32.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.2->wtpsplit<3.0.0,>=2.1.4->contextgem) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.2->wtpsplit<3.0.0,>=2.1.4->contextgem) (0.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.68.0->contextgem) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.68.0->contextgem) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.68.0->contextgem) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.68.0->contextgem) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.68.0->contextgem) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.68.0->contextgem) (1.20.0)
# Collecting docopt (from mosestokenizer->wtpsplit<3.0.0,>=2.1.4->contextgem)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting openfile (from mosestokenizer->wtpsplit<3.0.0,>=2.1.4->contextgem)
#   Downloading openfile-0.0.7-py3-none-any.whl.metadata (1.7 kB)
# Collecting uctools (from mosestokenizer->wtpsplit<3.0.0,>=2.1.4->contextgem)
#   Downloading uctools-1.3.0.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting toolwrapper (from mosestokenizer->wtpsplit<3.0.0,>=2.1.4->contextgem)
#   Downloading toolwrapper-2.1.0.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.8.8 in /usr/local/lib/python3.11/dist-packages (from skops->wtpsplit<3.0.0,>=2.1.4->contextgem) (0.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1->wtpsplit<3.0.0,>=2.1.4->contextgem) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm<2.0.0,>=1.68.0->contextgem) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm<2.0.0,>=1.68.0->contextgem) (2.4.0)
# Downloading contextgem-0.4.0-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 4.0 MB/s eta 0:00:00
# Downloading aiolimiter-1.2.1-py3-none-any.whl (6.7 kB)
# Downloading litellm-1.70.2-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 62.1 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.1 MB/s eta 0:00:00
# Downloading python_ulid-3.0.0-py3-none-any.whl (11 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 9.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.9 MB/s eta 0:00:00
# Downloading wtpsplit-2.1.5-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 kB 11.0 MB/s eta 0:00:00
# Downloading adapters-1.2.0-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 21.9 MB/s eta 0:00:00
# Downloading openai-1.75.0-py3-none-any.whl (646 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.0/647.0 kB 37.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading cached_property-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading skops-0.11.0-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 kB 12.0 MB/s eta 0:00:00
# Downloading openfile-0.0.7-py3-none-any.whl (2.4 kB)
# Building wheels for collected packages: mosestokenizer, docopt, toolwrapper, uctools
#   Building wheel for mosestokenizer (setup.py) ... done
#   Created wheel for mosestokenizer: filename=mosestokenizer-1.2.1-py3-none-any.whl size=49172 sha256=88564e91f8b33f15f0130f89bfe1b052d819f24ead30a05e15c61cbfabed3a3c
#   Stored in directory: /root/.cache/pip/wheels/34/cc/6e/444b747bf2adc6a0530acd6a7afda9f908b219906cfd4df2e7
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=2b46ec533828d409c3c0052e6909d2ee229a8f03ed35c593aaa9d4a9202a6c9d
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for toolwrapper (setup.py) ... done
#   Created wheel for toolwrapper: filename=toolwrapper-2.1.0-py3-none-any.whl size=3337 sha256=1d4c7646c34301acd5a0d1b76ce19bdfa89ce7b652fd533836c90994d717de85
#   Stored in directory: /root/.cache/pip/wheels/28/b0/06/bccd361b5b8bbf1ec88b72164fa52daaaa2221865fb980dff1
#   Building wheel for uctools (setup.py) ... done
#   Created wheel for uctools: filename=uctools-1.3.0-py3-none-any.whl size=6147 sha256=c7cd739466c053434c8fa0b3fbee64b430c9dced95618712e2edadca0cb34671
#   Stored in directory: /root/.cache/pip/wheels/ad/d6/21/763477f07e94a9d2567147f91d34897dfd1eb1062350302969
# Successfully built mosestokenizer docopt toolwrapper uctools
# Installing collected packages: toolwrapper, openfile, docopt, uctools, python-ulid, python-dotenv, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, loguru, cached_property, aiolimiter, nvidia-cusparse-cu12, nvidia-cudnn-cu12, mosestokenizer, skops, openai, nvidia-cusolver-cu12, litellm, adapters, wtpsplit, contextgem
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: openai
#     Found existing installation: openai 1.78.1
#     Uninstalling openai-1.78.1:
#       Successfully uninstalled openai-1.78.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed adapters-1.2.0 aiolimiter-1.2.1 cached_property-2.0.1 contextgem-0.4.0 docopt-0.6.2 litellm-1.70.2 loguru-0.7.3 mosestokenizer-1.2.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 openai-1.75.0 openfile-0.0.7 python-dotenv-1.1.0 python-ulid-3.0.0 skops-0.11.0 toolwrapper-2.1.0 uctools-1.3.0 wtpsplit-2.1.5

# %%
# Quick Start Example - Extracting aspect from a document

import os

from contextgem import Aspect, Document, DocumentLLM

# Example document instance
# Document content is shortened for brevity
doc = Document(
    raw_text=(
        "Consultancy Agreement\n"
        "This agreement between Company A (Supplier) and Company B (Customer)...\n"
        "The term of the agreement is 1 year from the Effective Date...\n"
        "The Supplier shall provide consultancy services as described in Annex 2...\n"
        "The Customer shall pay the Supplier within 30 calendar days of receiving an invoice...\n"
        "This agreement is governed by the laws of Norway...\n"
    ),
)

# Define an aspect with optional concept(s), using natural language
doc_aspect = Aspect(
    name="Governing law",
    description="Clauses defining the governing law of the agreement",
    reference_depth="sentences",
)

# Add aspects to the document
doc.add_aspects([doc_aspect])
# (add more aspects to the document, if needed)

# Create an LLM for extraction
llm = DocumentLLM(
    model="openai/gpt-4o-mini",  # or any other LLM from e.g. Anthropic, etc.
    api_key="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",  # your API key
)

# Extract information from the document
extracted_aspects = llm.extract_aspects_from_document(doc)
# or use async version llm.extract_aspects_from_document_async(doc)

# Access extracted information
print("Governing law aspect:")
print(
    extracted_aspects[0].extracted_items
)  # extracted aspect items with references to sentences
# or doc.get_aspect_by_name("Governing law").extracted_items
# Out:
# [contextgem] 2025-05-15 11:29:10.870 | INFO    | Text is being split into paragraphs, as no custom paragraphs were provided...
# [contextgem] 2025-05-15 11:29:10.873 | INFO    | Paragraphs are being split into sentences...
# [contextgem] 2025-05-15 11:29:10.875 | INFO    | Loading SaT model sat-3l-sm...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/965 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/855M [00:00<?, ?B/s]
# [contextgem] 2025-05-15 11:29:37.745 | INFO    | SaT model sat-3l-sm loaded.
# [contextgem] 2025-05-15 11:29:38.280 | SUCCESS | Process `Document initialization` finished in 27.41 seconds.
# [contextgem] 2025-05-15 11:29:38.497 | INFO    | Using model openai/gpt-4o-mini
# [contextgem] 2025-05-15 11:29:38.501 | INFO    | API base was not provided. Set `api_base`, if applicable.
# [contextgem] 2025-05-15 11:29:40.765 | SUCCESS | Process `Aspects extraction from document` finished in 2.26 seconds.
# Governing law aspect:
# [_StringItem(custom_data={}, value='This agreement is governed by the laws of Norway...', justification=None)]

# %%
# Quick Start Example - Extracting an aspect with sub-aspects

import os

from contextgem import Aspect, Document, DocumentLLM

# Sample document (content shortened for brevity)
contract_text = """
1. What are the constitutional options before a Governor when a Bill is presented to him under Article 200 of the Constitution of India?
2. Is the Governor bound by the aid & advice tendered by the Council of Ministers while exercising all the options available with him when a Bill is presented before him under Article 200 of the Constitution of India?
3. Is the exercise of constitutional discretion by the Governor under Article 200 of the Constitution of India justiciable?
4. Is Article 361 of the Constitution of India an absolute bar to the judicial review in relation to the actions of a Governor under Article 200 of the Constitution of India?
5. In the absence of a constitutionally prescribed time limit, and the manner of exercise of powers by the Governor, can timelines be imposed and the manner of exercise be prescribed through judicial orders for the exercise of all powers under Article 200 of the Constitution of India by the Governor?
6. Is the exercise of constitutional discretion by the President under Article 201 of the Constitution of India justiciable?
7. In the absence of a constitutionally prescribed timeline and the manner of exercise of powers by the President, can timelines be imposed and the manner of exercise be prescribed through judicial orders for the exercise of discretion by the President under Article 201 of the Constitution of India?
8. In light of the constitutional scheme governing the powers of the President, is the President required to seek advice of the Supreme Court by way of a reference under Article 143 of the Constitution of India and take the opinion of the Supreme Court when the Governor reserves a Bill for the President's assent or otherwise?
9. Are the decisions of the Governor and the President under Article 200 and Article 201 of the Constitution of India, respectively, justiciable at a stage anterior into the law coming into force? Is it permissible for the Courts to undertake judicial adjudication over the contents of a Bill, in any manner, before it becomes law?
10. Can the exercise of constitutional powers and the orders of/by the President / Governor be substituted in any manner under Article 142 of the Constitution of India?
11. Is a law made by the State legislature a law in force without the assent of the Governor granted under Article 200 of the Constitution of India?
12. In view of the proviso to Article 145(3) of the Constitution of India, is it not mandatory for any bench of this Hon'ble Court to first decide as to whether the question involved in the proceedings before it is of such a nature which involves substantial questions of law as to the interpretation of constitution and to refer it to a bench of minimum five Judges?
13. Do the powers of the Supreme Court under Article 142 of the Constitution of India limited to matters of procedural law or Article 142 of the Constitution of India extends to issuing directions /passing orders which are contrary to or inconsistent with existing substantive or procedural provisions of the Constitution or law in force?
14. Does the Constitution bar any other jurisdiction of the Supreme Court to resolve disputes between the Union Government and the State Governments except by way of a suit under Article 131 of the Constitution of India?
"""

doc = Document(raw_text=contract_text)

# Define termination aspect with practical sub-aspects
termination_aspect = Aspect(
    name="Constitution",
    description="Provisions related to body",
    aspects=[  # assign sub-aspects (optional)
        Aspect(
            name="State Government Rights",
            description="Conditions under which State Government has maximum rights",
        ),
        Aspect(
            name="'President's Rights",
            description="Conditions under which President has maximum rights",
        ),
        Aspect(
            name="Supreme Court Rights",
            description="Conditions under which Supreme Court has maximum rights",
        ),
        Aspect(
            name="Governor Rights",
            description="Conditions under which Governor has maximum rights"
        ),
    ],
)

# Add the aspect to the document. Sub-aspects are added with the parent aspect.
doc.add_aspects([termination_aspect])
# (add more aspects to the document, if needed)

# Create an LLM for extraction
llm = DocumentLLM(
    model="openai/gpt-4o-mini",  # or any other LLM from e.g. Anthropic, etc.
    api_key="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",  # your API key of the LLM provider
)

# Extract all information from the document
doc = llm.extract_all(doc)

# Get results with references in the document object
print("\n Constitution aspect:\n")
termination_aspect = doc.get_aspect_by_name("Constitution")
for sub_aspect in termination_aspect.aspects:
    print(sub_aspect.name)
    for item in sub_aspect.extracted_items:
        print(item.value)
    print("\n")
# Out:
# [contextgem] 2025-05-15 11:42:56.234 | INFO    | Text is being split into paragraphs, as no custom paragraphs were provided...
# [contextgem] 2025-05-15 11:42:56.239 | INFO    | Paragraphs are being split into sentences...
# [contextgem] 2025-05-15 11:42:57.157 | SUCCESS | Process `Document initialization` finished in 0.92 seconds.
# [contextgem] 2025-05-15 11:42:57.223 | INFO    | Using model openai/gpt-4o-mini
# [contextgem] 2025-05-15 11:42:57.224 | INFO    | API base was not provided. Set `api_base`, if applicable.
# [contextgem] 2025-05-15 11:42:59.827 | INFO    | Extracting sub-aspects for aspect `Constitution`
# [contextgem] 2025-05-15 11:42:59.828 | INFO    | Text is being set from paragraphs...
# [contextgem] 2025-05-15 11:42:59.829 | SUCCESS | Process `Document initialization` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.121 | SUCCESS | Process `Aspects extraction from document` finished in 7.29 seconds.
# [contextgem] 2025-05-15 11:43:07.125 | SUCCESS | Process `Aspects extraction from document` finished in 9.9 seconds.
# [contextgem] 2025-05-15 11:43:07.126 | INFO    | Extracting concepts from sub-aspects for aspect `Constitution`
# [contextgem] 2025-05-15 11:43:07.127 | INFO    | Text is being set from paragraphs...
# [contextgem] 2025-05-15 11:43:07.128 | SUCCESS | Process `Document initialization` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.131 | SUCCESS | Process `Concept extraction from aspect` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.132 | INFO    | Text is being set from paragraphs...
# [contextgem] 2025-05-15 11:43:07.133 | SUCCESS | Process `Document initialization` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.136 | SUCCESS | Process `Concept extraction from aspect` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.140 | INFO    | Text is being set from paragraphs...
# [contextgem] 2025-05-15 11:43:07.141 | SUCCESS | Process `Document initialization` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.143 | SUCCESS | Process `Concept extraction from aspect` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.145 | INFO    | Text is being set from paragraphs...
# [contextgem] 2025-05-15 11:43:07.146 | SUCCESS | Process `Document initialization` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.149 | SUCCESS | Process `Concept extraction from aspect` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.150 | SUCCESS | Process `Concept extraction from aspect` finished in 0.02 seconds.
# [contextgem] 2025-05-15 11:43:07.151 | SUCCESS | Process `Concepts extraction from document` finished in 0.0 seconds.
# [contextgem] 2025-05-15 11:43:07.152 | SUCCESS | Process `All aspects and concepts extraction` finished in 9.92 seconds.
#
#  Constitution aspect:
#
# State Government Rights
# 1. What are the constitutional options before a Governor when a Bill is presented to him under Article 200 of the Constitution of India?
# 2. Is the Governor bound by the aid & advice tendered by the Council of Ministers while exercising all the options available with him when a Bill is presented before him under Article 200 of the Constitution of India?
# 3. Is the exercise of constitutional discretion by the Governor under Article 200 of the Constitution of India justiciable?
# 4. Is Article 361 of the Constitution of India an absolute bar to the judicial review in relation to the actions of a Governor under Article 200 of the Constitution of India?
# 5. In the absence of a constitutionally prescribed time limit, and the manner of exercise of powers by the Governor, can timelines be imposed and the manner of exercise be prescribed through judicial orders for the exercise of all powers under Article 200 of the Constitution of India by the Governor?
# 11. Is a law made by the State legislature a law in force without the assent of the Governor granted under Article 200 of the Constitution of India?
#
#
# 'President's Rights
# 6. Is the exercise of constitutional discretion by the President under Article 201 of the Constitution of India justiciable?
# 7. In the absence of a constitutionally prescribed timeline and the manner of exercise of powers by the President, can timelines be imposed and the manner of exercise be prescribed through judicial orders for the exercise of discretion by the President under Article 201 of the Constitution of India?
# 8. In light of the constitutional scheme governing the powers of the President, is the President required to seek advice of the Supreme Court by way of a reference under Article 143 of the Constitution of India and take the opinion of the Supreme Court when the Governor reserves a Bill for the President's assent or otherwise?
# 9. Are the decisions of the Governor and the President under Article 200 and Article 201 of the Constitution of India, respectively, justiciable at a stage anterior into the law coming into force? Is it permissible for the Courts to undertake judicial adjudication over the contents of a Bill, in any manner, before it becomes law?
# 10. Can the exercise of constitutional powers and the orders of/by the President / Governor be substituted in any manner under Article 142 of the Constitution of India?
#
#
# Supreme Court Rights
# 12. In view of the proviso to Article 145(3) of the Constitution of India, is it not mandatory for any bench of this Hon'ble Court to first decide as to whether the question involved in the proceedings before it is of such a nature which involves substantial questions of law as to the interpretation of constitution and to refer it to a bench of minimum five Judges?
# 13. Do the powers of the Supreme Court under Article 142 of the Constitution of India limited to matters of procedural law or Article 142 of the Constitution of India extends to issuing directions /passing orders which are contrary to or inconsistent with existing substantive or procedural provisions of the Constitution or law in force?
# 14. Does the Constitution bar any other jurisdiction of the Supreme Court to resolve disputes between the Union Government and the State Governments except by way of a suit under Article 131 of the Constitution of India?
#
#
# Governor Rights
# 1. What are the constitutional options before a Governor when a Bill is presented to him under Article 200 of the Constitution of India?
# 2. Is the Governor bound by the aid & advice tendered by the Council of Ministers while exercising all the options available with him when a Bill is presented before him under Article 200 of the Constitution of India?
# 3. Is the exercise of constitutional discretion by the Governor under Article 200 of the Constitution of India justiciable?
# 4. Is Article 361 of the Constitution of India an absolute bar to the judicial review in relation to the actions of a Governor under Article 200 of the Constitution of India?
# 5. In the absence of a constitutionally prescribed time limit, and the manner of exercise of powers by the Governor, can timelines be imposed and the manner of exercise be prescribed through judicial orders for the exercise of all powers under Article 200 of the Constitution of India by the Governor?
# 11. Is a law made by the State legislature a law in force without the assent of the Governor granted under Article 200 of the Constitution of India?
